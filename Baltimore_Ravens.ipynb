# %%
import pandas as pd

# %%
# Ravens Data

ravens_data = [
    {
        "Quarterback": "Joe Flacco",
        "Era": "2008-2018",
        "Games_Played": 163,
        "Games_Started": 163,
        "QB_Wins": 96,
        "QB_Losses": 67,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.589,
        "Pass_Yards": 38245,
        "Pass_TDs": 212,
        "Passer_Rating": 84.1,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Lamar Jackson",
        "Era": "2018-Present",
        "Games_Played": 116,
        "Games_Started": 107,
        "QB_Wins": 76,
        "QB_Losses": 31,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.710,
        "Pass_Yards": 22608,
        "Pass_TDs": 187,
        "Passer_Rating": 102.2,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Kyle Boller",
        "Era": "2003-2005, 2007",
        "Games_Played": 53,
        "Games_Started": 42,
        "QB_Wins": 20,
        "QB_Losses": 22,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.476,
        "Pass_Yards": 7846,
        "Pass_TDs": 45,
        "Passer_Rating": 71.9,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Vinny Testaverde",
        "Era": "1996-1997",
        "Games_Played": 29,
        "Games_Started": 29,
        "QB_Wins": 8,
        "QB_Losses": 20,
        "QB_Ties": 1,
        "QB_Win_Pct": 0.293,
        "Pass_Yards": 7148,
        "Pass_TDs": 51,
        "Passer_Rating": 82.8,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Steve McNair",
        "Era": "2006-2007",
        "Games_Played": 22,
        "Games_Started": 22,
        "QB_Wins": 15,
        "QB_Losses": 7,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.682,
        "Pass_Yards": 4163,
        "Pass_TDs": 18,
        "Passer_Rating": 79.9,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Tony Banks",
        "Era": "1999-2000",
        "Games_Played": 26,
        "Games_Started": 18,
        "QB_Wins": 11,
        "QB_Losses": 7,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.611,
        "Pass_Yards": 3714,
        "Pass_TDs": 25,
        "Passer_Rating": 75.7,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Anthony Wright",
        "Era": "2003, 2005",
        "Games_Played": 16,
        "Games_Started": 14,
        "QB_Wins": 7,
        "QB_Losses": 7,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.500,
        "Pass_Yards": 2781,
        "Pass_TDs": 15,
        "Passer_Rating": 71.9,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Elvis Grbac",
        "Era": "2001",
        "Games_Played": 14,
        "Games_Started": 14,
        "QB_Wins": 8,
        "QB_Losses": 6,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.571,
        "Pass_Yards": 3033,
        "Pass_TDs": 15,
        "Passer_Rating": 71.1,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Jim Harbaugh",
        "Era": "1998",
        "Games_Played": 14,
        "Games_Started": 12,
        "QB_Wins": 5,
        "QB_Losses": 7,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.417,
        "Pass_Yards": 1839,
        "Pass_TDs": 12,
        "Passer_Rating": 72.9,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Tyler Huntley",
        "Era": "2021-2023, 2025",
        "Games_Played": 25,
        "Games_Started": 11,
        "QB_Wins": 5,
        "QB_Losses": 6,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.455,
        "Pass_Yards": 2383,
        "Pass_TDs": 10,
        "Passer_Rating": 83.0,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Jeff Blake",
        "Era": "2002",
        "Games_Played": 11,
        "Games_Started": 10,
        "QB_Wins": 4,
        "QB_Losses": 6,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.400,
        "Pass_Yards": 2084,
        "Pass_TDs": 13,
        "Passer_Rating": 77.3,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Trent Dilfer",
        "Era": "2000",
        "Games_Played": 11,
        "Games_Started": 8,
        "QB_Wins": 7,
        "QB_Losses": 1,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.875,
        "Pass_Yards": 1502,
        "Pass_TDs": 12,
        "Passer_Rating": 76.6,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Eric Zeier",
        "Era": "1997-1998",
        "Games_Played": 16,
        "Games_Started": 7,
        "QB_Wins": 3,
        "QB_Losses": 4,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.429,
        "Pass_Yards": 2367,
        "Pass_TDs": 12,
        "Passer_Rating": 87.3,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    },
    {
        "Quarterback": "Chris Redman",
        "Era": "2002",
        "Games_Played": 11,
        "Games_Started": 6,
        "QB_Wins": 3,
        "QB_Losses": 3,
        "QB_Ties": 0,
        "QB_Win_Pct": 0.500,
        "Pass_Yards": 1111,
        "Pass_TDs": 7,
        "Passer_Rating": 71.3,
        "Playoff_Appearances": 16,
        "Divisional_Titles": 8,
        "SuperBowl_Appearances": 2,
        "SuperBowl_Wins": 2
    }
]

ravens_df = pd.DataFrame(ravens_data)

print("Baltimore Ravens DataFrame:")
print(ravens_df)

print("\nShape of DataFrame:")
print(ravens_df.shape)

print("\nQuarterbacks sorted by win percentage:")
print(
    ravens_df[["Quarterback", "QB_Wins", "QB_Losses", "QB_Win_Pct"]]
    .sort_values(by="QB_Win_Pct", ascending=False)
)
# Out:
# Baltimore Ravens DataFrame:
#          Quarterback              Era  Games_Played  Games_Started  QB_Wins  \
# 0         Joe Flacco        2008-2018           163            163       96
# 1      Lamar Jackson     2018-Present           116            107       76
# 2        Kyle Boller  2003-2005, 2007            53             42       20
# 3   Vinny Testaverde        1996-1997            29             29        8
# 4       Steve McNair        2006-2007            22             22       15
# 5         Tony Banks        1999-2000            26             18       11
# 6     Anthony Wright       2003, 2005            16             14        7
# 7        Elvis Grbac             2001            14             14        8
# 8       Jim Harbaugh             1998            14             12        5
# 9      Tyler Huntley  2021-2023, 2025            25             11        5
# 10        Jeff Blake             2002            11             10        4
# ...

# %%
# Headcoaches for during each Quarterback's era

ravens_df["Head_Coach"] = [
    "Brian Billick / John Harbaugh",  # Joe Flacco
    "John Harbaugh",                  # Lamar Jackson
    "Brian Billick",                  # Kyle Boller
    "Ted Marchibroda",               # Vinny Testaverde
    "Brian Billick",                  # Steve McNair
    "Brian Billick",                  # Tony Banks
    "Brian Billick",                  # Anthony Wright
    "Brian Billick",                  # Elvis Grbac
    "Ted Marchibroda",               # Jim Harbaugh
    "John Harbaugh",                  # Tyler Huntley
    "Brian Billick",                  # Jeff Blake
    "Brian Billick",                  # Trent Dilfer
    "Ted Marchibroda / Brian Billick",# Eric Zeier
    "Brian Billick"                   # Chris Redman
]

print(ravens_df)
# Out:
#          Quarterback              Era  Games_Played  Games_Started  QB_Wins  \
# 0         Joe Flacco        2008-2018           163            163       96
# 1      Lamar Jackson     2018-Present           116            107       76
# 2        Kyle Boller  2003-2005, 2007            53             42       20
# 3   Vinny Testaverde        1996-1997            29             29        8
# 4       Steve McNair        2006-2007            22             22       15
# 5         Tony Banks        1999-2000            26             18       11
# 6     Anthony Wright       2003, 2005            16             14        7
# 7        Elvis Grbac             2001            14             14        8
# 8       Jim Harbaugh             1998            14             12        5
# 9      Tyler Huntley  2021-2023, 2025            25             11        5
# 10        Jeff Blake             2002            11             10        4
# ...

# %%
# Sorted by Quarterback's win percentage

ravens_df = ravens_df.sort_values(by="QB_Win_Pct", ascending=False).reset_index(drop=True)

print(ravens_df[["Quarterback", "QB_Wins", "QB_Losses", "QB_Win_Pct"]])
# Out:
#          Quarterback  QB_Wins  QB_Losses  QB_Win_Pct
# 0       Trent Dilfer        7          1       0.875
# 1      Lamar Jackson       76         31       0.710
# 2       Steve McNair       15          7       0.682
# 3         Tony Banks       11          7       0.611
# 4         Joe Flacco       96         67       0.589
# 5        Elvis Grbac        8          6       0.571
# 6     Anthony Wright        7          7       0.500
# 7       Chris Redman        3          3       0.500
# 8        Kyle Boller       20         22       0.476
# 9      Tyler Huntley        5          6       0.455
# 10        Eric Zeier        3          4       0.429
# 11      Jim Harbaugh        5          7       0.417
# 12        Jeff Blake        4          6       0.400
# 13  Vinny Testaverde        8         20       0.293

# %%
# Save to Excel file

ravens_df_sorted = ravens_df.sort_values(by="QB_Win_Pct", ascending=False).reset_index(drop=True)

ravens_df_sorted.to_excel("baltimore_ravens_quarterbacks_sorted.xlsx", index=False)

print("Sorted Excel file saved successfully.")
# Out:
# Sorted Excel file saved successfully.

# %%
# Remove Quarterback's with less than 10 wins

ravens_df_filtered = ravens_df[ravens_df["QB_Wins"] >= 10].reset_index(drop=True)
print(ravens_df_filtered[["Quarterback", "QB_Wins", "QB_Losses", "QB_Win_Pct"]])
# Out:
#      Quarterback  QB_Wins  QB_Losses  QB_Win_Pct
# 0  Lamar Jackson       76         31       0.710
# 1   Steve McNair       15          7       0.682
# 2     Tony Banks       11          7       0.611
# 3     Joe Flacco       96         67       0.589
# 4    Kyle Boller       20         22       0.476
